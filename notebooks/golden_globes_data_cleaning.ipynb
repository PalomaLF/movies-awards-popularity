# %%
import pandas as pd
import requests
import re
import cleaning_functions as cf

# %%
df_golden = pd.read_csv('../data/raw/golden_globe_awards.csv')

# %%
df_golden.drop('ceremony',axis=1,inplace=True)
df_golden.head(2)
# Out:
#    year_film  year_award                                           category  \
# 0       1943        1944  Best Performance by an Actress in a Supporting...
# 1       1943        1944  Best Performance by an Actor in a Supporting R...
#
#           nominee                     film   win
# 0  Katina Paxinou  For Whom The Bell Tolls  True
# 1   Akim Tamiroff  For Whom The Bell Tolls  True

# %%
df_golden.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year_film   7991 non-null   int64
#  1   year_award  7991 non-null   int64
#  2   category    7991 non-null   object
#  3   nominee     7991 non-null   object
#  4   film        6191 non-null   object
#  5   win         7991 non-null   bool
# dtypes: bool(1), int64(2), object(3)
# memory usage: 320.1+ KB

# %%
df_golden.category = df_golden.category.str.capitalize()

# %%
#eliminamos los mismos años que en oscars
df_golden = df_golden[df_golden.year_film >= 1967]
df_golden
# Out:
#       year_film  year_award  \
# 1308       1967        1968
# 1309       1967        1968
# 1310       1967        1968
# 1311       1967        1968
# 1312       1967        1968
# ...         ...         ...
# 7986       2019        2020
# 7987       2019        2020
# 7988       2019        2020
# 7989       2019        2020
# 7990       2019        2020
#
#                                                category  \
# 1308                        Best motion picture - drama
# 1309                        Best motion picture - drama
# 1310                        Best motion picture - drama
# 1311                        Best motion picture - drama
# 1312                        Best motion picture - drama
# ...                                                 ...
# 7986  Best performance by an actor in a supporting r...
# 7987  Best performance by an actor in a supporting r...
# 7988  Best performance by an actor in a supporting r...
# 7989                             Cecil b. demille award
# 7990                                Carol burnett award
#
#                            nominee        film    win
# 1308      In the Heat of the Night         NaN   True
# 1309              Bonnie and Clyde         NaN  False
# 1310    Far From The Madding Crowd         NaN  False
# 1311  Guess Who's Coming To Dinner         NaN  False
# 1312                 In Cold Blood         NaN  False
# ...                            ...         ...    ...
# 7986                 Kieran Culkin  Succession  False
# 7987                  Andrew Scott     Fleabag  False
# 7988                 Henry Winkler       Barry  False
# 7989                     Tom Hanks         NaN  False
# 7990               Ellen DeGeneres         NaN  False
#
# [6683 rows x 6 columns]

# %%
df_golden.isnull().sum()
# Out:
# year_film        0
# year_award       0
# category         0
# nominee          0
# film          1501
# win              0
# dtype: int64

# %%
nan_rows_golden = df_golden[df_golden.film.isnull()]

# %%
#parece que el nombre de las películas nominadas a premios de películas aparecen en nominee y no en film
nan_rows_golden
# Out:
#       year_film  year_award                        category  \
# 1308       1967        1968     Best motion picture - drama
# 1309       1967        1968     Best motion picture - drama
# 1310       1967        1968     Best motion picture - drama
# 1311       1967        1968     Best motion picture - drama
# 1312       1967        1968     Best motion picture - drama
# ...         ...         ...                             ...
# 7916       2019        2020  Best motion picture - animated
# 7917       2019        2020  Best motion picture - animated
# 7918       2019        2020  Best motion picture - animated
# 7989       2019        2020          Cecil b. demille award
# 7990       2019        2020             Carol burnett award
#
#                            nominee film    win
# 1308      In the Heat of the Night  NaN   True
# 1309              Bonnie and Clyde  NaN  False
# 1310    Far From The Madding Crowd  NaN  False
# 1311  Guess Who's Coming To Dinner  NaN  False
# 1312                 In Cold Blood  NaN  False
# ...                            ...  ...    ...
# 7916                Lion King, The  NaN  False
# 7917                   Toy Story 4  NaN  False
# 7918                     Frozen II  NaN  False
# 7989                     Tom Hanks  NaN  False
# 7990               Ellen DeGeneres  NaN  False
#
# [711 rows x 6 columns]

# %%
#primero eliminamos las filas con categorías sobre televisión, ya que nuestro estudio se centra en cine/películas
tv_categories = cf.values_iterable_regex(df_golden.category,r'\b\w*television\w*\b')
df_golden = cf.drop_rows_by_value(df_golden,df_golden.category,tv_categories)
# Out:
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
# /Users/paloma/Desktop/Ironhack/movies-awards-popularity/notebooks/cleaning_functions.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df= df.drop(df[df_column == l].index)
