# %%
import requests
from bs4 import BeautifulSoup as bs
import re
import cleaning_functions as cf
import pandas as pd

# %%
#Ahora extraeremos un nuevo df con información sobre el rating de las películas que ya tenemos de la API de TMDb.
#Para eso necesitamos una lista con las películas a buscar (la sacamos de award_winning_movies) cambiando espacios y caracteres no alfanuméricos por una clave concreta

# %%
url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjNmQxYjFjNGYyY2YzM2I5NTVhMGExN2MzN2YxMTc0NiIsInN1YiI6IjY1YmI3NDI1NzY0NmZkMDE4NGJkZjhmYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.259BtpIIcsim1ykSzWx0SlO8dv_e5wYLHcBAldMq8cM"
}

response = requests.get(url, headers=headers)

# %%
award_winning_movies = pd.read_csv('../data/Clean/3_award_winning_movies.csv')

# %%
movies = pd.DataFrame(award_winning_movies.film)

# %%
replace_movies_dictio = {
    "'":'%27',
    " ":'%20',
    ",":'%2C',
    "!":'%09',
    "(":'%28',
    ")":'%29',
    ":":'%3A',
    "?":'%3F',
    "$":'%24',
    "[":'%5B',
    "]":'%5D'
}

# %%
movies = cf.clean_strings_column (movies.film, replace_movies_dictio)

# %%
films_list = movies.to_list()

# %%
url = "https://api.themoviedb.org/3/search/movie?query=A%20Star%20Is%20Born&include_adult=false&language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjNmQxYjFjNGYyY2YzM2I5NTVhMGExN2MzN2YxMTc0NiIsInN1YiI6IjY1YmI3NDI1NzY0NmZkMDE4NGJkZjhmYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.259BtpIIcsim1ykSzWx0SlO8dv_e5wYLHcBAldMq8cM"
}

response = requests.get(url, headers=headers)
film = response.json()

# %%
film
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/dDYpjrwh1wNVQk0rEpc9P81wQt4.jpg',
#    'genre_ids': [10402, 18, 10749],
#    'id': 332562,
#    'original_language': 'en',
#    'original_title': 'A Star Is Born',
#    'overview': "Seasoned musician Jackson Maine discovers — and falls in love with — struggling artist Ally. She has just about given up on her dream to make it big as a singer — until Jack coaxes her into the spotlight. But even as Ally's career takes off, the personal side of their relationship is breaking down, as Jack fights an ongoing battle with his own internal demons.",
#    'popularity': 38.335,
#    'poster_path': '/wrFpXMNBRj2PBiN4Z5kix51XaIZ.jpg',
#    'release_date': '2018-10-03',
#    'title': 'A Star Is Born',
#    'video': False,
#    'vote_average': 7.501,
#    'vote_count': 11268},
#   {'adult': False,
#    'backdrop_path': '/kPn4M9dw7raRVQt2UPOWY0j2k0o.jpg',
#    'genre_ids': [18, 10402, 10749],
#    'id': 19610,
#    'original_language': 'en',
#    'original_title': 'A Star Is Born',
#    'overview': "Drunken, has-been rock star John Norman Howard falls in love with unknown singer Esther Hoffman after seeing her perform at a club. He lets her sing a few songs at one of his shows and she becomes the talk of the music industry. Esther's star begins to rise, while John's continues to fall. She tries desperately to get John to sober up and focus on his music, but it may be too late to save him.",
#    'popularity': 15.406,
#    'poster_path': '/oVpUzCimMZ0ecni7lDuYPuRdxoQ.jpg',
#    'release_date': '1976-12-17',
#    'title': 'A Star Is Born',
#    'video': False,
#    'vote_average': 6.0,
#    'vote_count': 208},
#   {'adult': False,
#    'backdrop_path': '/AlvKqnxlkWWYE6ngRLOWfYY3QuI.jpg',
#    'genre_ids': [18, 10402, 10749],
#    'id': 3111,
#    'original_language': 'en',
#    'original_title': 'A Star Is Born',
#    'overview': 'A movie star helps a young singer-actress find fame, even as age and alcoholism send his own career into a downward spiral.',
#    'popularity': 11.284,
#    'poster_path': '/zpg2SzpYhZk1D1seDfIIlwaqAxT.jpg',
#    'release_date': '1954-10-01',
#    'title': 'A Star Is Born',
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 278},
#   {'adult': False,
#    'backdrop_path': '/mBgYaGRKpZq4EPLkgq66kKJvp0d.jpg',
#    'genre_ids': [18, 10749],
#    'id': 22692,
#    'original_language': 'en',
#    'original_title': 'A Star Is Born',
#    'overview': 'Esther Blodgett is just another starry-eyed farm kid trying to break into the movies. Waitressing at a Hollywood party, she catches the eye of her idol Norman Maine, is sent for a screen test, and before long attains stardom as newly minted Vicki Lester. She and Norman marry, though his career soon dwindles to nothing due to his chronic alcoholism.',
#    'popularity': 11.556,
#    'poster_path': '/90EfCmXXWOs5dy7rHTNvGT9T8Kz.jpg',
#    'release_date': '1937-04-27',
#    'title': 'A Star Is Born',
#    'video': False,
#    'vote_average': 7.174,
#    'vote_count': 192},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99, 10402],
#    'id': 554861,
#    'original_language': 'sr',
#    'original_title': 'Zvezda je rođena',
#    'overview': 'This is a film about fulfilling dreams. This is a film about winning the battle against yourself. Vanja is 29 years old, she is a professional filmmaker, and she has nothing to do with the music business or the profession in general, apart from being a huge fan of her favorite performers. She will form a tribute to an American band "The Decemberists", whose song "I Was Meant for the Stage" inspired her. She booked a concert before she ever sat behind a drum set and long before her band ever existed. The film follows the entire process - from the idea, organizing the audition, forming the band, all through her struggle with learning, practicing hard and reaching her ultimate goal - playing the concert at the end. The mindset of the documentary is to show the enthusiasm that youth holds within its\' age and how each individual can truly achieve whatever one may put his or her mind to, as long as the heart is in the right place.',
#    'popularity': 0.6,
#    'poster_path': '/lzGOpG4exH67nwN2cAZUoq7INFN.jpg',
#    'release_date': '2010-04-20',
#    'title': 'A Star Is Born',
#    'video': False,
#    'vote_average': 0.0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 257003,
#    'original_language': 'en',
#    'original_title': 'A Porn Star Is Born',
#    'overview': 'Beautiful Aliana Love moves to Los Angeles with dreams of becoming a star, but quickly realizes that, in Hollywood, you are either on the plate or in front of it.  Financial woes force a reluctant but desperate Aliana into the seedy world of adult films, and porn king John Goldman is only too happy to exploit her looks and innocence - turning her into the biggest, X-rated contract star in years.',
#    'popularity': 3.416,
#    'poster_path': '/k5PP63NM6O1SV2HmaqiYMqHVECk.jpg',
#    'release_date': '2012-11-06',
#    'title': 'A Porn Star Is Born',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 21},
#   {'adult': False,
#    'backdrop_path': '/43KY7TozLdKBBYtXGQ3IfN7mirj.jpg',
#    'genre_ids': [16],
#    'id': 1036794,
#    'original_language': 'ja',
#    'original_title': '映画かいけつゾロリ ラララ♪スターたんじょう',
#    'overview': 'Zorori, Ishishi and Noshishi become agents and producers of a promising but troubled singer named Hippopo and help her on her way to stardom.',
#    'popularity': 3.717,
#    'poster_path': '/1TRma5LvtjLZIHUZq1VydXPN4vh.jpg',
#    'release_date': '2022-12-09',
#    'title': 'Zorori the Naughty Hero: La La La♪ A Star is Born',
#    'video': False,
#    'vote_average': 7.0,
#    'vote_count': 2},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 1054876,
#    'original_language': 'fr',
#    'original_title': 'Lady Gaga, a Star Is Born',
#    'overview': 'Eccentric and provocative, Lady Gaga is undoubtedly the greatest pop diva. The one who is actually called Stefani Germanotta is a brilliant artist, capable of all the excesses, but also a wounded woman, marked by a terrible drama. An artist who had to fight and overcome many humiliations to reach the top. Today, Lady Gaga is an undisputed music star with 230 million records sold, and a film icon thanks to the film "A Star is Born" and her role in "House of Gucci". In less than 15 years, she has become one of the most influential women in the world. To better understand her, those who have known her since her early days reveal her secrets and tell the story behind the scenes of the films and songs that have built her legend.',
#    'popularity': 0.914,
#    'poster_path': '/3dNZlZ7eTJIpyPwkZdezY1mlG3E.jpg',
#    'release_date': '2022-11-24',
#    'title': 'Lady Gaga, a Star Is Born',
#    'video': False,
#    'vote_average': 9.0,
#    'vote_count': 1},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [18],
#    'id': 1187388,
#    'original_language': 'id',
#    'original_title': 'A Star is Fucking Born',
#    'overview': "Story of Alya, a Dangdut singer who face a debt collector that collect her mother's debt.",
#    'popularity': 0.968,
#    'poster_path': '/mviQTzi1rbCSl3qQeU5lKgtjk2i.jpg',
#    'release_date': '2023-09-01',
#    'title': 'A Star is Fucking Born',
#    'video': False,
#    'vote_average': 0.0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': '/bqtCBz3BTvY9cBedjpeeGSgk6MR.jpg',
#    'genre_ids': [99],
#    'id': 578547,
#    'original_language': 'en',
#    'original_title': 'The Road to Stardom: The Making of A Star is Born',
#    'overview': 'A look at the making of “A Star Is Born,” featuring director/star/writer/producer Bradley Cooper and star Lady Gaga, both of whom also wrote and produced many of the film’s songs, as well as performed them live for the movie.',
#    'popularity': 1.71,
#    'poster_path': '/mRlnPb85ZbAGpTYsWI57Huk1Ggt.jpg',
#    'release_date': '2018-12-07',
#    'title': 'The Road to Stardom: The Making of A Star is Born',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 11},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'id': 508601,
#    'original_language': 'en',
#    'original_title': 'A Star Is Born World Premiere',
#    'overview': 'Live television broadcast of the world premiere. Described by various participants as the biggest world premiere in memory, even bigger than the Academy Awards.',
#    'popularity': 2.223,
#    'poster_path': None,
#    'release_date': '1954-09-28',
#    'title': 'A Star Is Born World Premiere',
#    'video': False,
#    'vote_average': 8.0,
#    'vote_count': 2},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 662453,
#    'original_language': 'en',
#    'original_title': 'AOC: A Star Is Born',
#    'overview': 'Get a glimpse into the world of the youngest congress woman in history, AOC: A Star Is Born, puts the political heavy weight’s life and career in the spotlight.\xa0\xa0Speak your truth and stand for what you believe in!',
#    'popularity': 0.6,
#    'poster_path': '/gYyRelXQDOX3meIeEmlg7xqT7W1.jpg',
#    'release_date': '2019-01-01',
#    'title': 'AOC: A Star Is Born',
#    'video': True,
#    'vote_average': 0.0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [35, 10749],
#    'id': 1028428,
#    'original_language': 'tl',
#    'original_title': 'Kwatang: A Star Is Born',
#    'overview': '',
#    'popularity': 0.627,
#    'poster_path': '/o4ucvG9VWO7KZ74jxeeVCp0yGBO.jpg',
#    'release_date': '1967-01-14',
#    'title': 'Kwatang: A Star Is Born',
#    'video': False,
#    'vote_average': 0.0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 272885,
#    'original_language': 'en',
#    'original_title': 'Justin Bieber: A Star is Born',
#    'overview': 'Music - Justin Beiber was born to make music! Before he was 15 he taught himself to play the piano, drums, guitar, and trumpet. This documentary chronicles his life, and documents his transition from a street performer to a mega teen superstar. Everyday a child is born but on March 1st, 1994, "A Star Was Born." -  Justin Bieber',
#    'popularity': 0.6,
#    'poster_path': None,
#    'release_date': '2011-01-01',
#    'title': 'Justin Bieber: A Star is Born',
#    'video': False,
#    'vote_average': 1.0,
#    'vote_count': 3},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 314745,
#    'original_language': 'en',
#    'original_title': 'Chris Brown: A Star Is Born: Unauthorized',
#    'overview': 'This engrossing documentary looks at the life and skyrocketing career of rhythm-and-blues star Chris Brown. Only 17 years old, the talented artist has already achieved great success, receiving a number of Grammy nods and charting several top 10 and top 20 hits. Brown\'s self-titled debut album has sold more than 3 million copies, and his first single, "Run It," reached No. 1 on Billboard\'s Hot 100.',
#    'popularity': 0.6,
#    'poster_path': None,
#    'release_date': '',
#    'title': 'Chris Brown: A Star Is Born: Unauthorized',
#    'video': False,
#    'vote_average': 10.0,
#    'vote_count': 1},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [28, 18],
#    'id': 414975,
#    'original_language': 'ja',
#    'original_title': '悪太郎伝\u3000悪い星の下でも',
#    'overview': 'A young man with a strong sense of justice is torn between two girls: the flighty Taneko and the serious Suzuko. With wisdom, courage and honor in a Japanese spirit of manliness he wins the day.',
#    'popularity': 1.989,
#    'poster_path': '/b78yjHgtyFdI8djZ2jfSzZKmvGz.jpg',
#    'release_date': '1965-08-25',
#    'title': 'Born Under Crossed Stars',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 7}],
#  'total_pages': 1,
#  'total_results': 16}

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjNmQxYjFjNGYyY2YzM2I5NTVhMGExN2MzN2YxMTc0NiIsInN1YiI6IjY1YmI3NDI1NzY0NmZkMDE4NGJkZjhmYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.259BtpIIcsim1ykSzWx0SlO8dv_e5wYLHcBAldMq8cM"
}

for film in films_list:
    url = f'https://api.themoviedb.org/3/search/movie?query={film}&include_adult=false&language=en-US&page=1'
    response = requests.get(url, headers=headers)

print(response.text)
