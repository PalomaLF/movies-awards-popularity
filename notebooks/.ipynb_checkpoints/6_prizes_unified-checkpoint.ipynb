# %%
import pandas as pd
import re
import cleaning_functions as cf

# %%
oscars = pd.read_csv('../data/Clean/1_oscars_cleaned.csv')
oscars.head(10)
# Out:
#    year_film  year_ceremony          Oscars nominations                name  \
# 0       1967           1968     Actor in a leading role       Warren Beatty
# 1       1967           1968     Actor in a leading role      Dustin Hoffman
# 2       1967           1968     Actor in a leading role         Paul Newman
# 3       1967           1968     Actor in a leading role         Rod Steiger
# 4       1967           1968     Actor in a leading role       Spencer Tracy
# 5       1967           1968  Actor in a supporting role     John Cassavetes
# 6       1967           1968  Actor in a supporting role        Gene Hackman
# 7       1967           1968  Actor in a supporting role      Cecil Kellaway
# 8       1967           1968  Actor in a supporting role      George Kennedy
# 9       1967           1968  Actor in a supporting role  Michael J. Pollard
#
#                            film  Oscars winner
# 0              Bonnie and Clyde          False
# 1                  The Graduate          False
# 2                Cool Hand Luke          False
# 3      In the Heat of the Night           True
# 4  Guess Who's Coming to Dinner          False
# 5               The Dirty Dozen          False
# 6              Bonnie and Clyde          False
# 7  Guess Who's Coming to Dinner          False
# 8                Cool Hand Luke           True
# 9              Bonnie and Clyde          False

# %%
golden = pd.read_csv('../data/Clean/2_golden_final.csv')
golden.head(10)
# Out:
#    year_film  year_award                Golden Globes nominations  \
# 0       1967        1968              Best motion picture - drama
# 1       1967        1968              Best motion picture - drama
# 2       1967        1968              Best motion picture - drama
# 3       1967        1968              Best motion picture - drama
# 4       1967        1968              Best motion picture - drama
# 5       1967        1968  Best motion picture - musical or comedy
# 6       1967        1968  Best motion picture - musical or comedy
# 7       1967        1968  Best motion picture - musical or comedy
# 8       1967        1968  Best motion picture - musical or comedy
# 9       1967        1968  Best motion picture - musical or comedy
#
#                         nominee                          film  \
# 0      In the Heat of the Night      In the Heat of the Night
# 1              Bonnie and Clyde              Bonnie and Clyde
# 2    Far From The Madding Crowd    Far From The Madding Crowd
# 3  Guess Who's Coming To Dinner  Guess Who's Coming To Dinner
# 4                 In Cold Blood                 In Cold Blood
# 5             The Graduate, The                  The Graduate
# 6                       Camelot                       Camelot
# 7               Doctor Dolittle               Doctor Dolittle
# 8  The Taming of the Shrew, The       The Taming of the Shrew
# 9      Thoroughly Modern Millie      Thoroughly Modern Millie
#
#    Golden Globes winner
# 0                  True
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# 5                  True
# 6                 False
# 7                 False
# 8                 False
# 9                 False

# %%
#renombramos algunas columnas para mantener los datos claros después de unirlas:
golden.rename(columns={"nominee": "G.G. name", 'Golden Globes nominations':'G.G. nominations', 'Golden Globes winner':'G.G. winner'}, inplace=True)

# %%
oscars.rename(columns={"name": "Oscars name"}, inplace=True)

# %%
golden.rename(columns={"year_award": "year_ceremony"}, inplace=True)

# %%
golden.head(1)
# Out:
#    year_film  year_ceremony             G.G. nominations  \
# 0       1967           1968  Best motion picture - drama
#
#                   G.G. name                      film  G.G. winner
# 0  In the Heat of the Night  In the Heat of the Night         True

# %%
oscars.head(1)
# Out:
#    year_film  year_ceremony       Oscars nominations    Oscars name  \
# 0       1967           1968  Actor in a leading role  Warren Beatty
#
#                film  Oscars winner
# 0  Bonnie and Clyde          False

# %%
oscars.reset_index(drop = True, inplace = True)

# %%
#cambiamos el formato de los df con un pivot table para poder tener las categorías como nombres de columna expandidos para cada película (unmelt)

# %%
oscars_films = oscars.pivot_table(index= ['film','year_film','year_ceremony'], columns = 'Oscars nominations', values= 'Oscars winner')
oscars_films = oscars_films.reset_index()
oscars_films.columns.name = None
oscars_films.head(2)
# Out:
#                  film  year_film  year_ceremony  Actor in a leading role  \
# 0                '38'       1986           1987                      NaN
# 1  'Crocodile' Dundee       1986           1987                      NaN
#
#    Actor in a supporting role  Actress in a leading role  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
#
#    Actress in a supporting role  Adapted screenplay  Animated feature film  \
# 0                           NaN                 NaN                    NaN
# 1                           NaN                 0.0                    NaN
#
#    Best picture  ...  International feature film  Makeup and hairstyling  \
# 0           NaN  ...                         0.0                     NaN
# 1           NaN  ...                         NaN                     NaN
#
#    Original score  Original screenplay  Original song  Production design  \
# 0             NaN                  NaN            NaN                NaN
# 1             NaN                  NaN            NaN                NaN
#
#    Short film animated  Short film live action  Sound effects  Visual effects
# 0                  NaN                     NaN            NaN             NaN
# 1                  NaN                     NaN            NaN             NaN
#
# [2 rows x 27 columns]

# %%
golden_films = golden.pivot_table(index= ['film','year_film','year_ceremony'], columns = 'G.G. nominations', values= 'G.G. winner')
golden_films = golden_films.reset_index()
golden_films.columns.name = None
golden_films.head(2)
# Out:
#               film  year_film  year_ceremony  Best actor - drama  \
# 0      Roma (1972)       1972           1973                 NaN
# 1  $1,000,000 Duck       1971           1972                 NaN
#
#    Best actor - musical or comedy  Best actress - drama  \
# 0                             NaN                   NaN
# 1                             0.0                   NaN
#
#    Best actress - musical or comedy  Best director - motion picture  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
#
#    Best motion picture - animated  Best motion picture - drama  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
#
#    Best motion picture - foreign language  \
# 0                                     0.0
# 1                                     NaN
#
#    Best motion picture - musical or comedy  \
# 0                                      NaN
# 1                                      NaN
#
#    Best original score - motion picture  Best original song - motion picture  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
#
#    Best screenplay - motion picture  Best supporting actor - motion picture  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
#
#    Best supporting actress - motion picture  Documentary
# 0                                       NaN          NaN
# 1                                       NaN          NaN

# %%
#creamos tres columnas nuevas por cada df: 
    #número de nominaciones (contar columnas con valor distinto de NaN)
    #número de premios (sumar fila
    #y si han recibido el premio a la mejor película

# %%
oscars_films.columns
# Out:
# Index(['film', 'year_film', 'year_ceremony', 'Actor in a leading role',
#        'Actor in a supporting role', 'Actress in a leading role',
#        'Actress in a supporting role', 'Adapted screenplay',
#        'Animated feature film', 'Best picture', 'Cinematography',
#        'Costume design', 'Director', 'Documentary feature',
#        'Documentary feature film', 'Documentary short film', 'Film editing',
#        'International feature film', 'Makeup and hairstyling',
#        'Original score', 'Original screenplay', 'Original song',
#        'Production design', 'Short film animated', 'Short film live action',
#        'Sound effects', 'Visual effects'],
#       dtype='object')

# %%
for n in range(len(oscars_films)):
    oscars_films.iloc(l)
    oscars_films['Oscars total nominations'] = oscars_films.count(oscar_films.columns[3:])

# %%
len(oscars_films)
# Out:
# 2954

# %%
oscars_films.film[1]
# Out:
# "'Crocodile' Dundee"

# %%
list_all_films = []
list_oscars = oscars_films.film.to_list()
list_golden = golden_films.film.to_list()
list_all_films.extend([e for e in list_oscars])
list_all_films.extend([e for e in list_golden if e not in list_all_films])

# %%
len(list_all_films)
# Out:
# 3899

# %%
awarded_films = {
    'Films':list_all_films,
    'year_film': [],
    'Oscars nominations': [],
    'Oscars won': [],
    'Oscars best picture': [],
    'G.G. nominations': [],
    'G.G. won': [],
    'G.G. best motion picture': []
}
